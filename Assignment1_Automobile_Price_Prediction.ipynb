# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
automobile_df = pd.read_csv('/content/automobile.csv', index_col = False)

# %% [markdown]
# # Data Exploratory Analysis

# %% [markdown]
# ## Correlation Matrix in all columns of the dataset

# %%
corr = automobile_df.corr()

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_precision(2)\
# Out:
# <style  type="text/css" >
# #T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col0,#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col1,#T_a7bef950_2401_11ec_a706_0242ac1c0002row2_col2,#T_a7bef950_2401_11ec_a706_0242ac1c0002row3_col3,#T_a7bef950_2401_11ec_a706_0242ac1c0002row4_col4,#T_a7bef950_2401_11ec_a706_0242ac1c0002row5_col5,#T_a7bef950_2401_11ec_a706_0242ac1c0002row6_col6,#T_a7bef950_2401_11ec_a706_0242ac1c0002row7_col7,#T_a7bef950_2401_11ec_a706_0242ac1c0002row8_col8,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col9,#T_a7bef950_2401_11ec_a706_0242ac1c0002row10_col10,#T_a7bef950_2401_11ec_a706_0242ac1c0002row11_col11,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row13_col13,#T_a7bef950_2401_11ec_a706_0242ac1c0002row14_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row15_col15{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col1{
#             background-color:  #da4b68;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col2,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col2{
#             background-color:  #e6a0ae;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col3{
#             background-color:  #e8adb8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col4{
#             background-color:  #e3889a;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col5,#T_a7bef950_2401_11ec_a706_0242ac1c0002row13_col12{
#             background-color:  #ecc6ce;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col6{
#             background-color:  #e48e9f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col7,#T_a7bef950_2401_11ec_a706_0242ac1c0002row5_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row14_col2{
#             background-color:  #df6f85;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col8,#T_a7bef950_2401_11ec_a706_0242ac1c0002row7_col0,#T_a7bef950_2401_11ec_a706_0242ac1c0002row11_col5,#T_a7bef950_2401_11ec_a706_0242ac1c0002row14_col5{
#             background-color:  #ecc8cf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col9{
#             background-color:  #d94865;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col10,#T_a7bef950_2401_11ec_a706_0242ac1c0002row6_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col4{
#             background-color:  #e7a7b4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col11{
#             background-color:  #e0748a;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col5,#T_a7bef950_2401_11ec_a706_0242ac1c0002row2_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row3_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row4_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row5_col1,#T_a7bef950_2401_11ec_a706_0242ac1c0002row6_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row7_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row8_col13,#T_a7bef950_2401_11ec_a706_0242ac1c0002row8_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col0,#T_a7bef950_2401_11ec_a706_0242ac1c0002row10_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row11_col13,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col10,#T_a7bef950_2401_11ec_a706_0242ac1c0002row13_col11,#T_a7bef950_2401_11ec_a706_0242ac1c0002row14_col6,#T_a7bef950_2401_11ec_a706_0242ac1c0002row15_col14{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col13{
#             background-color:  #e17d91;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row10_col1{
#             background-color:  #e17c90;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row0_col15,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col5{
#             background-color:  #db5872;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col0,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col3{
#             background-color:  #e597a7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col2,#T_a7bef950_2401_11ec_a706_0242ac1c0002row15_col13{
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col3,#T_a7bef950_2401_11ec_a706_0242ac1c0002row2_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col6,#T_a7bef950_2401_11ec_a706_0242ac1c0002row13_col8{
#             background-color:  #de667e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col4{
#             background-color:  #e28497;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col6,#T_a7bef950_2401_11ec_a706_0242ac1c0002row3_col1,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col15{
#             background-color:  #e28698;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col7,#T_a7bef950_2401_11ec_a706_0242ac1c0002row5_col14,#T_a7bef950_2401_11ec_a706_0242ac1c0002row9_col6{
#             background-color:  #e7a3b0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col8,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col14{
#             background-color:  #e69dab;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col9,#T_a7bef950_2401_11ec_a706_0242ac1c0002row15_col0{
#             background-color:  #eab9c3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col10{
#             background-color:  #e491a1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col11,#T_a7bef950_2401_11ec_a706_0242ac1c0002row5_col7,#T_a7bef950_2401_11ec_a706_0242ac1c0002row12_col11{
#             background-color:  #edccd2;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_a7bef950_2401_11ec_a706_0242ac1c0002row1_col12,#T_a7bef950_2401_11ec_a706_0242ac1c0002row6_col10,#T_a7bef950_2401_11ec_a706_0242ac1c0002row10_col13{
#             background-color:  #e7eaef;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;

# %% [markdown]
# ## Datatypes of each column

# %%
automobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CompanyName       205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Checking for missing values
#
# We firstly see the number of entries in each column to see what fraction of the data is missing.

# %%
DATASET_SIZE = len(automobile_df['car_ID'])

print("Total number of entries in the data:", DATASET_SIZE)
# Out:
# Total number of entries in the data: 205

# %% [markdown]
# We then count the number of cells in each column that are missing.

# %%
automobile_df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CompanyName         0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# Hence, there are no missing values in any column of this dataset.

# %% [markdown]
# ## Make spellings of categories uniform
#
# Clearly, in the CompanyName column there are different spellings for the same company. We follow the below convention for naming:
# - Maxda = Mazda
# - Nissan = nissan
# - porcshce = porsche
# - toyouta = toyota
# - vokswagen = volkswagen
# - vw = volkswagen

# %%
automobile_df['CompanyName'].value_counts()
# Out:
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# bmw             8
# buick           8
# plymouth        7
# audi            7
# saab            6
# porsche         5
# isuzu           4
# chevrolet       3
# alfa-romero     3
# jaguar          3
# renault         2
# mercury         1
# Name: CompanyName, dtype: int64

# %%
correction = {'maxda': 'mazda',  'Nissan': 'nissan', 
               'porcshce': 'porsche', 'toyouta': 'toyota',
               'vokswagen': 'volkswagen', 'vw': 'volkswagen'}

for incorrect in correction:
    automobile_df.loc[automobile_df['CompanyName'] == incorrect, 'CompanyName'] = correction[incorrect]

# %% [markdown]
# ## Encoding categorical columns
#
# As observed above, the following columns have non-numerical data:
#
# - CompanyName
# - fueltype
# - aspiration
# - doornumber
# - carbody
# - drivewheel
# - enginelocation
# - enginetype
# - cylindernumber
# - fuelsystem

# %% [markdown]
# ### Label Encoding
#
# Out of the above, the columns fueltype, aspiration, enginelocation have only two types of values that they can take. Hence, we could use label encoding for these columns.

# %%
def fit_labels(column):
  unique_values = column.unique()
  for label, value in enumerate(unique_values):
    column = column.replace(value, label)
  return column

# %%
cols_to_label_encode = ['fueltype', 'aspiration', 'enginelocation']

for col_to_label_encode in cols_to_label_encode:
  automobile_df[col_to_label_encode] = fit_labels(automobile_df[col_to_label_encode])

# %% [markdown]
# Further, we have columns where the data given are numbers in words. For example: doornumber and cylindernumber.

# %%
words2num = {'two': 2, 'three': 3, 'four':4, 'five': 5, 'six': 6, 'eight': 8, 'twelve': 12}

cols_to_convert = ['doornumber', 'cylindernumber']

for col_to_convert in cols_to_convert:
  for word in words2num:
    automobile_df[col_to_convert] = automobile_df[col_to_convert].replace(word, words2num[word])

# %% [markdown]
# ### One Hot Encoding
#
# Now, the remaining columns have more than 2 categories and no categories where numbers are given in words. Hence, we use one-hot encoding for encoding categories given in these columns.
#
# Therefore, we see all the categories we have in the columns left.

# %%
cols_to_one_hot = ['CompanyName', 'carbody', 'drivewheel', 'enginetype', 'fuelsystem']

for col_to_one_hot in cols_to_one_hot:
  # Get all the unique values in a column
  col_types = automobile_df[col_to_one_hot].unique()

  # Insert all unique values as columns in the dataframe
  for col_type in col_types:
    automobile_df[col_type] = [0 for i in range(len(automobile_df['car_ID']))]
  
  # Set the value of the column with the same name as value in the cell.
  for i, cell in enumerate(automobile_df[col_to_one_hot]):
    automobile_df[cell][i] = 1

  automobile_df = automobile_df.drop(col_to_one_hot, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
automobile_df.head()
# Out:
#    car_ID  symboling  fueltype  aspiration  ...  spfi  4bbl  idi  spdi
# 0       1          3         0           0  ...     0     0    0     0
# 1       2          3         0           0  ...     0     0    0     0
# 2       3          1         0           0  ...     0     0    0     0
# 3       4          2         0           0  ...     0     0    0     0
# 4       5          2         0           0  ...     0     0    0     0
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Since the car ID column contains all unique elements and it's length is the same as the length of the dataset, there are no repeated rows.

# %%
automobile_df = automobile_df.drop(columns = 'car_ID')
automobile_df = automobile_df.drop_duplicates()

# %% [markdown]
# # Splitting into train and test sets
#
# We shuffle the data set and split it in two unequal parts: train set and test set.
#
# The smaller part of the dataset is the test set, while the larger is the train set.

# %%
import random

def train_test_split(train_percent, df, id_col):
  df = df.sample(frac=1).reset_index(drop=True)
  train_set_len = int(train_percent * len(df[id_col]))

  return df.head(train_set_len), df.tail(len(df[id_col]) - train_set_len)

# %%
train_set, test_set = train_test_split(0.7, automobile_df, 'price')

train_set_size = len(train_set)
test_set_size = len(test_set)

print("Size of the train set", train_set_size)
print("Size of the test set", test_set_size)
# Out:
# Size of the train set 143
# Size of the test set 62

# %%
train_y = train_set['price'].to_numpy()
train_x = train_set.drop(columns = 'price').to_numpy()
train_x = np.insert(train_x, 0, np.ones(143), axis=1)

# %%
test_y = test_set['price'].to_numpy()
test_x = test_set.drop(columns = 'price').to_numpy()
test_x = np.insert(test_x, 0, np.ones(205 - 143), axis=1)

# %% [markdown]
# ## Learning Algorithm
#
# We use the linear regression algorithm, wherein the weights are calculated by:
#
# w = inv(x) * y

# %% [markdown]
# ### Closed form solution

# %%
def transpose_product(x):
  return (x.T).dot(x)

# %%
def inverse(x):
  return np.linalg.inv(x)

# %%
def fit(x, y, lambda_coefficient):
  return (inverse(transpose_product(x) - lambda_coefficient * np.identity(65)).dot(x.T)).dot(y)

# %% [markdown]
# Since, the matrix transpose(X) * X is not invertible, we add a very small lambda correction to the matrix, so that it is invertible.

# %%
weights = fit(train_x, train_y, 0.000001)

# %% [markdown]
# # Inference Algorithm

# %%
def predict(x, weights):
  return x.dot(weights)

# %% [markdown]
# # Evaluation Metrics
#
# We use mean squared error in order to evaluate the model.

# %%
def mean_squared_error(x, w, y, n):
  return sum((predict(x_val, w) - y_val) ** 2 for x_val, y_val in zip(x, y)) / n

# %%
test_error_closed_form = mean_squared_error(test_x, weights, test_y, DATASET_SIZE)

# %%
train_error_closed_form = mean_squared_error(train_x, weights, train_y, DATASET_SIZE)

# %%
print("Error in the test set:", test_error_closed_form)
print("Error in the train set:", train_error_closed_form)
# Out:
# Error in the test set: 4403242.3075199
# Error in the train set: 1535627.6164094873

# %% [markdown]
# ### Gradient Descent Solution

# %%
def gd_predict(x, w, ind, no_of_features):
  return sum(w[i] * x[i] for i in range(no_of_features))

# %%
def derivative_wrt_weight(x, weight, ind, y, set_size, no_of_features):
  return (-2) * sum(x[i][ind] * (y[i] - gd_predict(x[i], weight, i, no_of_features)) for i in range(set_size))

# %%
def derivative_wrt_wt_vector(x, w_old, y, set_size, no_of_features):
  return np.asarray([derivative_wrt_weight(x, w_old, i, y, set_size, no_of_features) for i in range(no_of_features)])

# %%
def gd_fit(epochs, learning_rate, x, y, set_size, no_of_features):
  w_old = np.zeros(len(x[0]))
  
  for epoch_no in range(epochs):
    derivative_vector = derivative_wrt_wt_vector(x, w_old, y, set_size, no_of_features)
    w_old = w_old + learning_rate * derivative_vector

  return w_old

# %%
LEARNING_RATE = 0.0000000000000000000000000001
EPOCHS = 2

set_size, no_of_features = train_x.shape

gradient_desc_wts = gd_fit(EPOCHS, LEARNING_RATE, train_x, train_y, set_size, no_of_features)

# %%
test_error_gd = mean_squared_error(test_x, gradient_desc_wts, test_y, DATASET_SIZE)
train_error_gd = mean_squared_error(train_x, gradient_desc_wts, train_y, DATASET_SIZE)

# %%
print("Error in the test set:", test_error_gd)
print("Error in the train set:", train_error_gd)
# Out:
# Error in the test set: 79840066.60243903
# Error in the train set: 159941412.8887019

# %% [markdown]
# ### Newton's Method Solution

# %%
def double_derivative(x, w, k, j, set_size):
  return sum(x[i][j] * x[i][k] * 2 for i in range(set_size))

# %%
def compute_hessian(x, w):
  hessian = [[0 for j in range(len(w))] for i in range(len(w))]

  for i in range(len(w)):
    for j in range(len(w)):
      hessian[i][j] = double_derivative(x, w, i, j, set_size)
  
  return hessian

# %%
def fit_newtons_method(x, y, epochs, lambda_correction, set_size, no_of_features):
  w = np.zeros(no_of_features)

  for epoch in range(epochs):
    gradient = derivative_wrt_wt_vector(x, w, y, set_size, no_of_features)
    hessian = (np.linalg.inv(compute_hessian(x, w) - lambda_correction * 
                           np.identity(no_of_features)))
    w = w - hessian.dot(gradient)

  return w

# %%
newton_mtd_wts = fit_newtons_method(train_x, train_y, 3, 0.00001, set_size, no_of_features)

# %%
test_error_newtons_mtd = mean_squared_error(test_x, newton_mtd_wts, test_y, DATASET_SIZE)
train_error_newtons_mtd = mean_squared_error(train_x, newton_mtd_wts, train_y, DATASET_SIZE)

# %%
print("Error in the test set:", test_error_newtons_mtd)
print("Error in the train set:", train_error_newtons_mtd)
# Out:
# Error in the test set: 4403476.468809987
# Error in the train set: 1535627.6161937353
